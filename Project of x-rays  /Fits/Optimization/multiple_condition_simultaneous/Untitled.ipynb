# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
os.system("wolframscript new.wls 100 50 10 0 33 0 62.1 229 9 35.5 7.5 7.5 27 15")
# Out:
# 0

# %%
exp=np.loadtxt("exp/REFL_166630_custom_A_thick_pH10_reduced abriged.txt")
dyn=np.loadtxt("dyt/rod0.txt")

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(dyn[:,0],(dyn[:,1]),label='Dyt')
plt.yscale('log')
plt.legend()
plt.xlim(0,0.12)
plt.show()

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
plt.yscale('log')
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.12)
plt.show()

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.14)
plt.show()

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.14)
plt.show()

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.18)
plt.show()

# %%
plt.plot(exp[:,0],exp[:,1],label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.18)
plt.show()

# %%
plt.plot(exp[:,0],np.log10(exp[:,1]),label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0]/10,(dyn[:,1]),label='Dyt',color='red')
#plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.18)
plt.show()

# %%
plt.plot(exp[:,0],np.log10(exp[:,1]),label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0],np.log10(dyn[:,1]),label='Dyt',color='red')
#plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.18)
plt.show()

# %%
plt.plot(exp[:,0],np.log10(exp[:,1]),label='Exp')
plt.plot(4*3.14*0.002618/dyn[:,0],(dyn[:,1]),label='Dyt',color='red')
#plt.yscale('log')
plt.xscale("log")
plt.title('16662, three layer')
plt.legend()
plt.xlim(0,0.18)
plt.show()
