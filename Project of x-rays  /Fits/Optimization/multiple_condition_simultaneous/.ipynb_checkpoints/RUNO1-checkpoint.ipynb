# %%
import cma
import os
import numpy as np
import func 
import time
import shutil
import matplotlib.pylab as plt

# %% [markdown]
# This part is for determining input parameters

# %% [markdown]
# ### Structural input

# %%
code='new.wls' #name of the mathematica code
d=141 #periodic length of grating 140
rho=19
fd=4 #the filling factor out of 10
fbd=6#filling factor of bottom layer out of 10
ftd=4.5 #filling factor of top layer out of 10
t=31 #grating thickness middle part
tc=10 #thickness of other parts

# %% [markdown]
# ### Experimental data path

# %%
exp='exp/average/'
rods_number=[3,4,5]

# %% [markdown]
# ### Cma-es package input

# %%
dimension=6 #number of structural parameters to be predicted.
tol=10e-6
X=[d,rho,fd,fbd,ftd,t]#series of initial guess 
popsize=5 #number of different solutions each time package provides, and need to be evaluated
std=2.49

# %% [markdown]
# ### Output files

# %%
output=open('output.txt','w')
log=open('log.txt','w')
product=open('product.txt','w')
cnt=0

# %% [markdown]
# ### Code criteria

# %%
threshold=0.08 #minium which result should be in this span to have an acceptable result
sleep_time=30 #in seconds. This is the time for "popsize" number of simulation to be completed. 
cnt=0

# %% [markdown]
# ### Function for fitting

# %%
Ubound=np.array([148,23,6.25,6.25,6.25,40])
Lbound=np.array([132,15,3.75,3.75,3.75,30])
es = cma.CMAEvolutionStrategy( X, std,{'popsize':popsize,'tolfun':tol,'bounds':[Lbound,Ubound]})
# Out:
# (2_w,5mirr1)-aCMA-ES (mu_w=1.6,w_1=73%) in dimension 6 (seed=576883, Thu Mar 11 14:56:14 2021)

# %%
while not es.stop():
    fit=np.zeros((1,popsize))
    solutions=es.ask()     
    print('start the game')
    for i in range(popsize):
        print(solutions[i])
        print(func.seq(np.array(solutions[i]).tolist()))
        print('func.simulation6(%s,%s)'%(code,func.seq(np.array(solutions[i]).tolist())))
        v=np.array(solutions[i]).tolist()
        s=func.simulation6(code,v[0],v[1],v[2],v[3],v[4],v[5]) 
       # shutil.move('sample.txt', 'sample7.txt')
       # os.system('mv C:\Users\hrahmani\Desktop\Optimization\Process_of_fitting\Main\test\multiple_condition_simultaneous_three_variables\sample.txt C:\Users\hrahmani\Desktop\Optimization\Process_of_fitting\Main\test\multiple_condition_simultaneous_three_variables\sample7.txt')
       # n=func.simulation4(code,v[0],v[1],v[2],v[3],v[4],v[5])
      #  shutil.move('sample.txt', 'sample4.txt')
        print('v0=%s v1=%s v2=%s v3=%s v4=%s v5=%s'%(v[0],v[1],v[2],v[3],v[4],v[5]))
        time.sleep(sleep_time)
        print('sleep time is over')
        
        for j in range(-15,0):
            fff=open('dyt/rod=%s.txt'%(j),'r')
            d=fff.readlines()
            fdat=open('dyt/rods=%s.txt'%j,'w')
            mat=[]
            lnd=len(d)
            for lines in range(len(d)):
                lns=d[lines]
                for let in range(len(lns)):
                    if lns[let]=='A':
                        mat.append(lines)
            n=list(set(mat))
            new = [x for x in range(len(d)) if x not in n]
            for numbers in new:
                fdat.write(d[numbers]+'\n')
            fff.close()
            fdat.close()
            fdata=np.loadtxt('dyt/rods=%s.txt'%j) 
            fdatas=smooth(fdata[:,1],3)
            maxi=np.max(fdatas)
            dta=open('dyt/rodn=%s.txt'%j,'w')
            for k in range(len(fdata)):
                if fdata[k,1]>0 and fdata[k,0]<0.8:
                    dta.write('%s %s\n'%(fdata[k,0],fdatas[k]/maxi))
            dta.close()
        fitn_matrix=[]
        for m in rods_number:
            sim_data=('dyt/rodn=-%s.txt'%m)
            exp_data=('exp/average/l=%s.dat'%m)
            fit_number=func.fitness(sim_data,exp_data)
            print('fitness number for rod %s is %s'%(m,fit_number))
            fitn_matrix.append(fit_number)
            #visualization
            thery=np.loadtxt('dyt/rodn=-%s.txt'%m)
            exyp=np.loadtxt('exp/average/l=%s.dat'%m)
            plt.plot(thery[:,0],thery[:,1],label='theory')
            plt.plot(exyp[:,0],exyp[:,1],label='exyp')
            plt.legend()
            plt.yscale('log')
            plt.show()           
        fitness_number=np.mean(fitn_matrix)
        print('fitness is %s'%fitness_number)
        fit[0][i]=fitness_number
        log.write('%s simulation number%s\n'%(cnt,i))
        print('%s simulation number%s\n'%(cnt,i))
    fit=np.array(fit).tolist()[0]
    output.write('%s %s %s \n'%(cnt,solutions,fit)) 
    print('%s %s %s \n'%(cnt,solutions,fit))
    es.tell(solutions,fit)
    ftn=es.result[1]
    newsol=es.result[0]
    cnt+=1
    output.write('new solution is %s with %s as fitness criteria\n\n #### \n'%(newsol,ftn))
    print('new solution is %s with %s as fitness criteria\n\n##########\n'%(newsol,ftn))
    product.write('%s %s\n'%(cnt,ftn)) 
    
    if (np.abs(ftn)<threshold):
        break
        output.write('last line shows the solution')
output.close()
log.close()
product.close()
# Out:
# start the game
# [141.10288791  22.40655077   5.62206672   6.24192668   5.42528435
#   30.01852574]
# 141.102887911, 22.4065507725, 5.62206672237, 6.24192667932, 5.42528435455, 30.0185257394
# func.simulation6(new.wls,141.102887911, 22.4065507725, 5.62206672237, 6.24192667932, 5.42528435455, 30.0185257394)
# v0=141.102887911 v1=22.4065507725 v2=5.62206672237 v3=6.24192667932 v4=5.42528435455 v5=30.0185257394
# sleep time is over
# fitness number for rod 3 is 0.7569812791368689
# fitness number for rod 4 is 0.8373731799997189
# fitness number for rod 5 is 0.8453439839236756
# fitness is 0.8132328143534212
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f560317ce4b5> in <module>()
#      60         print('fitness is %s'%fitness_number)
#      61         fit[0][i]=fitness_number
# ---> 62         log.write('%s simulation number%s\n'%(cnt,i))
#      63         print('%s simulation number%s\n'%(cnt,i))
#      64     fit=np.array(fit).tolist()[0]
#
# ValueError: I/O operation on closed file

# %%
print(np.abs(-6))
# Out:
# 6

# %%
a=3
c=5
print(np.max([a,c]))
# Out:
# 5

# %%
solutions=es.ask() 
print(solutions[0])
print(func.seq(np.array(solutions[0]).tolist()))
#print('func.simulation6(%s,%s)'%(code,func.seq(np.array(solutions[i]).tolist())))
# Out:
# [123.1803174    4.97462669   5.72933444   6.41543749  29.04282089
#   12.35085007]
# 123.180317401, 4.9746266915, 5.72933444175, 6.41543748652, 29.0428208887, 12.3508500701

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth
