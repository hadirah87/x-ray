# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
exp=np.loadtxt("exp/intensity_file_Mathew669.dat")
dyt=np.loadtxt("dyt/testdata.txt")

# %%
plt.plot(exp[:,0]+0.45,np.log10(exp[:,1])-1.05)
plt.plot(dyt[:,0]*10,dyt[:,1])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
