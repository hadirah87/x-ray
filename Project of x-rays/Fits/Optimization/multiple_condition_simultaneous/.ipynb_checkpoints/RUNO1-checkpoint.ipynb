# %%
import cma
import os
import numpy as np
import functions as func 
import time
import shutil
import matplotlib.pylab as plt

# %% [markdown]
# This part is for determining input parameters

# %% [markdown]
# ### Structural input

# %%
code='new.wls' #name of the mathematica code
d=141 #periodic length of grating 140

fd=50 #the filling factor out of 10
fbd=50#filling factor of bottom layer out of 10
ftd=50 #filling factor of top layer out of 10
t=31 #grating thickness middle part
tc=10 #thickness of other parts
rho=10
delta=-0.0096

# %% [markdown]
# ### Experimental data path

# %%
exp='exp/average/'
rods_number=[1,3,5]

# %% [markdown]
# ### Cma-es package input

# %%
dimension=6 #number of structural parameters to be predicted.
tol=10e-6
X=[d,fd,fbd,ftd,t,rho]#series of initial guess 
popsize=10 #number of different solutions each time package provides, and need to be evaluated
std=3.5

# %% [markdown]
# ### Output files

# %%
output=open('output.txt','w')
log=open('log.txt','w')
product=open('product.txt','w')
cnt=0

# %% [markdown]
# ### Code criteria

# %%
threshold=0.003 #minium which result should be in this span to have an acceptable result
sleep_time=30 #in seconds. This is the time for "popsize" number of simulation to be completed. 
cnt=0

# %% [markdown]
# ### Function for fitting

# %%
Ubound=np.array([141.75,51.5,51.5,51.5,35,11])
Lbound=np.array([138,46.5,46.5,46.5,30,6])
es = cma.CMAEvolutionStrategy( X, std,{'popsize':popsize,'tolfun':tol,'bounds':[Lbound,Ubound]})
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 6 (seed=599653, Tue Jun 28 17:23:01 2022)

# %%
while not es.stop():
    fit=np.zeros((1,popsize))
    solutions=es.ask()     
    print('start the game')
    for i in range(popsize):
        print(solutions[i])
        print(func.seq(np.array(solutions[i]).tolist()))
        print('func.simulation6(%s,%s)'%(code,func.seq(np.array(solutions[i]).tolist())))
        v=np.array(solutions[i]).tolist()
        s=func.simulation6(code,v[0],v[1],v[2],v[3],v[4],v[5]) 
        print('v0=%s v1=%s v2=%s v3=%s v4=%s v5=%s'%(v[0],v[1],v[2],v[3],v[4],v[5]))
        time.sleep(sleep_time)
        print('sleep time is over')
        
        for j in rods_number:
            fff=open('dyt/rod=%s.txt'%(j),'r')
            d=fff.readlines()
            fdat=open('dyt/rods=%s.txt'%j,'w')
            mat=[]
            lnd=len(d)
            for lines in range(len(d)):
                lns=d[lines]
                for let in range(len(lns)):
                    if lns[let]=='A':
                        mat.append(lines)
            n=list(set(mat))
            new = [x for x in range(len(d)) if x not in n]
            for numbers in new:
                fdat.write(d[numbers]+'\n')
            fff.close()
            fdat.close()
            fdata=np.loadtxt('dyt/rods=%s.txt'%j) 
            fdatas=fdata[:,1]
#            fdatas=smooth(fdata[:,1],1)
            maxi=np.max(fdatas)
            dta=open('dyt/rodm=%s.txt'%j,'w')
            for k in range(len(fdata)):
#                if fdata[k,1]>0 and fdata[k,0]<0.85:
                dta.write('%s %s\n'%(fdata[k,0],fdatas[k]/maxi))
            dta.close()
            
            fdata_m=np.loadtxt('dyt/rodm=%s.txt'%j)
            exp_m=('exp/average/final_average/m=%s.dat'%j)
            sim_m=('dyt/rodm=%s.txt'%j) 
            deltfit=func.findmine(exp_m,sim_m,delta)
            dta_m=open('dyt/rodn=%s.txt'%j,'w')
            for k in range(len(fdata_m)):
                dta_m.write('%s %s\n'%(fdata_m[k,0],(fdata_m[k,1]+deltfit)))
            dta_m.close()
            
        fitn_matrix=[]
        for m in rods_number:
            sim_data=('dyt/rodn=%s.txt'%m)
            exp_data=('exp/average/final_average/m=%s.dat'%m)
            fit_number=func.fitness(sim_data,exp_data)
            print('fitness number for rod %s is %s'%(m,fit_number))
            fitn_matrix.append(fit_number)
            #visualization
            thery=np.loadtxt('dyt/rodn=%s.txt'%m)
            exyp=np.loadtxt('exp/average/final_average/m=%s.dat'%m)
            plt.plot(thery[:,0],np.log10(thery[:,1]),label='theory')
            plt.plot(exyp[:,0],np.log10(exyp[:,1]),label='exyp')
            plt.legend()
            #plt.yscale('log')
            plt.show()           
        fitness_number=np.mean(fitn_matrix)
        print('fitness is %s'%fitness_number)
        fit[0][i]=fitness_number
        log.write('%s simulation number%s\n'%(cnt,i))
        print('%s simulation number%s\n'%(cnt,i))
    fit=np.array(fit).tolist()[0]
    output.write('%s %s %s \n'%(cnt,solutions,fit)) 
    print('%s %s %s \n'%(cnt,solutions,fit))
    es.tell(solutions,fit)
    ftn=es.result[1]
    newsol=es.result[0]
    cnt+=1
    output.write('new solution is %s with %s as fitness criteria\n\n #### \n'%(newsol,ftn))
    print('new solution is %s with %s as fitness criteria\n\n##########\n'%(newsol,ftn))
    product.write('%s %s\n'%(cnt,ftn)) 
    
    if (np.abs(ftn)<threshold):
        break
        output.write('last line shows the solution')
output.close()
log.close()
product.close()
# Out:
# start the game
# [140.63075807  47.79867331  46.52432692  47.95856017  32.74120596
#    9.98964866]
# 140.63075806814877, 47.79867330780638, 46.52432692261325, 47.95856017055616, 32.7412059629254, 9.98964866156183
# func.simulation6(new.wls,140.63075806814877, 47.79867330780638, 46.52432692261325, 47.95856017055616, 32.7412059629254, 9.98964866156183)
# v0=140.63075806814877 v1=47.79867330780638 v2=46.52432692261325 v3=47.95856017055616 v4=32.7412059629254 v5=9.98964866156183
# sleep time is over
# fitness number for rod 1 is 4.4067909622467205
# <ipython-input-36-c4e7956b7daa>:61: RuntimeWarning: invalid value encountered in log10
#   plt.plot(thery[:,0],np.log10(thery[:,1]),label='theory')
# fitness number for rod 3 is 6.637681712148572
# <ipython-input-36-c4e7956b7daa>:61: RuntimeWarning: invalid value encountered in log10
#   plt.plot(thery[:,0],np.log10(thery[:,1]),label='theory')
# fitness number for rod 5 is 5.052865140162206
# <ipython-input-36-c4e7956b7daa>:61: RuntimeWarning: invalid value encountered in log10
#   plt.plot(thery[:,0],np.log10(thery[:,1]),label='theory')
# fitness is 5.365779271519166
# 0 simulation number0
#
# [139.54318267  51.48035567  49.94547612  49.56666424  30.02957665
#   10.97986894]
# 139.54318267477385, 51.48035566911521, 49.94547612081936, 49.56666424273982, 30.029576653000298, 10.979868936542228
# func.simulation6(new.wls,139.54318267477385, 51.48035566911521, 49.94547612081936, 49.56666424273982, 30.029576653000298, 10.979868936542228)
# v0=139.54318267477385 v1=51.48035566911521 v2=49.94547612081936 v3=49.56666424273982 v4=30.029576653000298 v5=10.979868936542228
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-c4e7956b7daa> in <module>
#      10         s=func.simulation6(code,v[0],v[1],v[2],v[3],v[4],v[5])
#      11         print('v0=%s v1=%s v2=%s v3=%s v4=%s v5=%s'%(v[0],v[1],v[2],v[3],v[4],v[5]))
# ---> 12         time.sleep(sleep_time)
#      13         print('sleep time is over')
#      14
#
# KeyboardInterrupt:

# %%
print(np.abs(-6))
# Out:
# 6

# %%
a=3
c=5
print(np.max([a,c]))
# Out:
# 5

# %%
solutions=es.ask() 
print(solutions[0])
print(func.seq(np.array(solutions[0]).tolist()))
#print('func.simulation6(%s,%s)'%(code,func.seq(np.array(solutions[i]).tolist())))
# Out:
# [123.1803174    4.97462669   5.72933444   6.41543749  29.04282089
#   12.35085007]
# 123.180317401, 4.9746266915, 5.72933444175, 6.41543748652, 29.0428208887, 12.3508500701

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth
